# %%
import jieba
import sys

from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfVectorizer

from jieba import analyse

# %%
#每個字詞的tf-idf值
corpus = []
with open('data_fishcomment.txt', 'r', encoding="utf-8") as f:
    for line in f:
        corpus.append(" ".join(jieba.cut(line.split(',')[0], cut_all=False)))

vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(corpus)
print (tfidf.shape)

words = vectorizer.get_feature_names()
for i in range(len(corpus)):
    print ('----Document %d----' % (i))
    for j in range(len(words)):
        if tfidf[i,j] > 1e-5:
              print (words[j], tfidf[i,j])
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\super\AppData\Local\Temp\jieba.cache
# Loading model cost 1.238 seconds.
# Prefix dict has been built succesfully.
# (1, 282)
# ----Document 0----
# cp 0.02577696311132335
# 一個 0.02577696311132335
# 一定 0.0515539262226467
# 一張 0.02577696311132335
# 一番 0.02577696311132335
# 一種 0.02577696311132335
# 一處 0.0515539262226467
# 一間 0.0515539262226467
# 七折 0.02577696311132335
# 上二樓 0.02577696311132335
# 上岸 0.02577696311132335
# 不少 0.02577696311132335
# 不自在 0.02577696311132335
# 不錯 0.0515539262226467
# 中心 0.02577696311132335
# 乾淨 0.07733088933397006
# 二樓 0.02577696311132335
# 享用 0.02577696311132335
# 人員 0.02577696311132335
# 人大 0.02577696311132335
# 人超 0.02577696311132335
# 介紹 0.0515539262226467
# 他們 0.07733088933397006
# 代客 0.07733088933397006
# 以量 0.02577696311132335
# 便宜 0.2062157048905868
# 個門 0.02577696311132335
# 值得 0.02577696311132335
# 值高 0.02577696311132335
# 假日 0.02577696311132335
# ...

# %%
jieba.set_dictionary("dict.txt.big.txt")
# 將關鍵字詞取出來 
# topK代表要取的關鍵字次數 
with open("data_fishcomment.txt", "rb") as f:
    for line in f:
        tags = jieba.analyse.extract_tags(line,
                                          topK=10, 
                                          withWeight=True)
        for tag, weight in tags:
            print(tag + "," + str(int(weight * 10000)))
# Out:
# Building prefix dict from C:\Program Files (x86)\Python37-32\Scripts\dict.txt.big.txt ...
# Dumping model to file cache C:\Users\super\AppData\Local\Temp\jieba.uf4b9437c9785bb271210948ab5875331.cache
# Loading model cost 2.119 seconds.
# Prefix dict has been built succesfully.
# 新鮮,6187
# 海鮮,3217
# 種類,1980
# 價格,1732
# 好吃,1509
# 服務,1485
# 還有,1237
# 選擇,1237
# 東西,1237
# 料理,1035

# %%
#取出 10大關鍵字
with open("data_fishcomment.txt", 'r', encoding="utf-8") as f:
    for line in f:
        tags = jieba.analyse.extract_tags(line,10)
        print(",".join(tags))
# Out:
# 新鮮,海鮮,種類,價格,好吃,服務,還有,選擇,東西,料理
